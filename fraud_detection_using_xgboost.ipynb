# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import joblib
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import VotingClassifier
from sklearn. metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from datetime import datetime
from imblearn.under_sampling import RandomUnderSampler

# %%
data_train = pd.read_csv("fraudTrain.csv")
data_test = pd.read_csv("fraudTest.csv")

# %%
data_train.columns, data_test.columns
# Out:
# (Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#         'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#         'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#         'merch_lat', 'merch_long', 'is_fraud'],
#        dtype='object'),
#  Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#         'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#         'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#         'merch_lat', 'merch_long', 'is_fraud'],
#        dtype='object'))

# %%
data = pd.concat([data_train, data_test], axis=0)

# %%
data.head(2)
# Out:
#    Unnamed: 0 trans_date_trans_time            cc_num  \
# 0           0   2019-01-01 00:00:18  2703186189652095
# 1           1   2019-01-01 00:00:44      630423337322
#
#                           merchant     category     amt      first   last  \
# 0       fraud_Rippin, Kub and Mann     misc_net    4.97   Jennifer  Banks
# 1  fraud_Heller, Gutmann and Zieme  grocery_pos  107.23  Stephanie   Gill
#
#   gender                        street  ...      lat      long  city_pop  \
# 0      F                561 Perry Cove  ...  36.0788  -81.1781      3495
# 1      F  43039 Riley Greens Suite 393  ...  48.8878 -118.2105       149
#
#                                  job         dob  \
# 0          Psychologist, counselling  1988-03-09
# 1  Special educational needs teacher  1978-06-21
#
#                           trans_num   unix_time  merch_lat  merch_long  \
# 0  0b242abb623afc578575680df30655b9  1325376018  36.011293  -82.048315
# 1  1f76529f8574734946361c461b024d99  1325376044  49.159047 -118.186462
#
#    is_fraud
# 0         0
# 1         0
#
# [2 rows x 23 columns]

# %%
data.shape
# Out:
# (1852394, 23)

# %%
df = data.copy()

# %%
df.shape
# Out:
# (1852394, 23)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'trans_date_trans_time', 'cc_num', 'merchant', 'category',
#        'amt', 'first', 'last', 'gender', 'street', 'city', 'state', 'zip',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'unix_time',
#        'merch_lat', 'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.drop(columns = [df.columns[0], df.columns[2], df.columns[6], df.columns[7], df.columns[9],  "trans_num"], inplace=True)

# %%
df.head(2)
# Out:
#   trans_date_trans_time                         merchant     category     amt  \
# 0   2019-01-01 00:00:18       fraud_Rippin, Kub and Mann     misc_net    4.97
# 1   2019-01-01 00:00:44  fraud_Heller, Gutmann and Zieme  grocery_pos  107.23
#
#   gender            city state    zip      lat      long  city_pop  \
# 0      F  Moravian Falls    NC  28654  36.0788  -81.1781      3495
# 1      F          Orient    WA  99160  48.8878 -118.2105       149
#
#                                  job         dob   unix_time  merch_lat  \
# 0          Psychologist, counselling  1988-03-09  1325376018  36.011293
# 1  Special educational needs teacher  1978-06-21  1325376044  49.159047
#
#    merch_long  is_fraud
# 0  -82.048315         0
# 1 -118.186462         0

# %%
sampler = RandomUnderSampler(random_state=42)

X = df.drop('is_fraud', axis=1)
y = df['is_fraud']

X_resampled, y_resampled = sampler.fit_resample(X, y)

# %%
X_resampled.shape, y_resampled.shape
# Out:
# ((19302, 16), (19302,))

# %%
new_df = X_resampled.copy()

# %%
new_df["is_fraud"] = y_resampled

# %%
new_df.sample(2)
# Out:
#        trans_date_trans_time                 merchant     category     amt  \
# 743217   2019-11-14 02:28:01  fraud_McDermott-Weimann  grocery_pos  281.70
# 638426   2019-09-29 00:56:08   fraud_Rutherford-Mertz  grocery_pos  367.28
#
#        gender        city state    zip      lat     long  city_pop  \
# 743217      M  Washington    DC  20017  38.9367 -76.9940    601723
# 638426      F  Ronceverte    WV  24970  37.7418 -80.4626      4575
#
#                            job         dob   unix_time  merch_lat  merch_long  \
# 743217  Psychotherapist, child  1991-02-04  1352860081  39.719166  -77.961174
# 638426            Statistician  1991-10-22  1348880168  37.493973  -81.328101
#
#         is_fraud
# 743217         1
# 638426         1

# %%
new_df.isnull().sum()
# Out:
# trans_date_trans_time    0
# merchant                 0
# category                 0
# amt                      0
# gender                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %%
from math import radians, sin, cos, sqrt, atan2

def haversine_distance(lat1, lon1, lat2, lon2):
    R = 6371  # Radius of Earth in kilometers
    lat1_rad, lon1_rad = radians(lat1), radians(lon1)
    lat2_rad, lon2_rad = radians(lat2), radians(lon2)
    dlat = lat2_rad - lat1_rad
    dlon = lon2_rad - lon1_rad
    a = sin(dlat / 2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %%
new_df["distance"] = new_df.apply(lambda row: haversine_distance(row['lat'], row['long'], row['merch_lat'], row['merch_long']), axis=1)

# %%
new_df.drop(columns = ["lat", "long", "merch_lat", "merch_long"], inplace = True)

# %%
new_df.sample(2)
# Out:
#        trans_date_trans_time                  merchant       category     amt  \
# 869027   2019-12-19 22:28:57   fraud_Hackett-Lueilwitz    grocery_pos  312.80
# 991203   2020-02-09 03:02:33  fraud_Conroy-Cruickshank  gas_transport    6.26
#
#        gender      city state    zip  city_pop                    job  \
# 869027      M  Columbia    SC  29209    333497    Mechanical engineer
# 991203      F     Delhi    LA  71232      6581  Multimedia programmer
#
#                dob   unix_time  is_fraud   distance
# 869027  1968-03-19  1355956137         1  89.331353
# 991203  1964-02-13  1360378953         1  40.091678

# %%
new_df["dob"].dtype
# Out:
# dtype('O')

# %%
new_df["dob"] = pd.to_datetime(new_df["dob"])

# %%
def calculate_age(dob):
    today = datetime.today()
    age = today.year - dob.year
    if (today.month, today.day) < (dob.month, dob.day):
        age -= 1
    return age

# %%
new_df['age'] = new_df['dob'].apply(calculate_age)

# %%
new_df.drop(columns = ["dob"], inplace = True)

# %%
new_df.sample(2)
# Out:
#        trans_date_trans_time                               merchant  \
# 407731   2019-07-04 00:50:05  fraud_Altenwerth, Cartwright and Koss
# 548386   2020-12-29 21:00:12                    fraud_Bode-Schuster
#
#             category      amt gender   city state    zip  city_pop  \
# 407731  shopping_net  1032.41      F   Jelm    WY  82063       100
# 548386     kids_pets    45.33      F  Uledi    PA  15484       328
#
#                      job   unix_time  is_fraud    distance  age
# 407731  Public librarian  1341363005         1  115.588674   50
# 548386      Tree surgeon  1388350812         0   62.298359   41

# %%
merchant_groups = new_df.groupby('merchant')
fraud_percentage_dict = {}

for merchant, group in merchant_groups:
    total_trans = group.shape[0]
    total_fraud_trans = group[group["is_fraud"] == 1].shape[0]
    fraud_percentage_dict[merchant] = (total_fraud_trans / total_trans) * 100

new_df["fraud_merchant_pct"] = new_df["merchant"].map(fraud_percentage_dict)

# %%
# Step 1: Rank merchants based on their fraud percentages
# Sort fraud_percentage_dict by fraud percentage
sorted_fraud_percentage = sorted(fraud_percentage_dict.items(), key=lambda x: x[1])

# Create a dictionary for ordinal encoding
merchant_ordinal_dict = {merchant: rank + 1 for rank, (merchant, _) in enumerate(sorted_fraud_percentage)}

# Step 2: Map the ordinal encoding back to the DataFrame
new_df["merchant_ordinal"] = new_df["merchant"].map(merchant_ordinal_dict)

# %%
new_df[(new_df["fraud_merchant_pct"] == new_df["fraud_merchant_pct"].max())& new_df["is_fraud"] == 1]
# Out:
#         trans_date_trans_time                                 merchant  \
# 21668     2019-01-13 23:45:34  fraud_Parisian, Schiller and Altenwerth
# 49909     2019-01-29 22:05:23  fraud_Parisian, Schiller and Altenwerth
# 72074     2019-02-12 01:54:28  fraud_Parisian, Schiller and Altenwerth
# 74075     2019-02-12 22:22:25  fraud_Parisian, Schiller and Altenwerth
# 276198    2019-05-16 22:03:23  fraud_Parisian, Schiller and Altenwerth
# 344578    2019-06-10 23:13:35  fraud_Parisian, Schiller and Altenwerth
# 395807    2019-06-29 22:55:56  fraud_Parisian, Schiller and Altenwerth
# 552077    2019-08-24 12:14:49  fraud_Parisian, Schiller and Altenwerth
# 569571    2019-08-30 15:59:43  fraud_Parisian, Schiller and Altenwerth
# 635379    2019-09-27 20:53:21  fraud_Parisian, Schiller and Altenwerth
# 673054    2019-10-13 22:16:37  fraud_Parisian, Schiller and Altenwerth
# 746726    2019-11-15 23:24:34  fraud_Parisian, Schiller and Altenwerth
# 987747    2020-02-07 03:02:31  fraud_Parisian, Schiller and Altenwerth
# 1059729   2020-03-16 02:37:23  fraud_Parisian, Schiller and Altenwerth
# 1068939   2020-03-19 22:06:33  fraud_Parisian, Schiller and Altenwerth
# 1097512   2020-03-31 22:56:56  fraud_Parisian, Schiller and Altenwerth
# 1186843   2020-05-11 01:46:53  fraud_Parisian, Schiller and Altenwerth
# 1222953   2020-05-25 23:24:08  fraud_Parisian, Schiller and Altenwerth
# 1228626   2020-05-27 22:32:54  fraud_Parisian, Schiller and Altenwerth
# 1290489   2020-06-18 23:33:13  fraud_Parisian, Schiller and Altenwerth
# 1290504   2020-06-18 23:38:27  fraud_Parisian, Schiller and Altenwerth
# 58974     2020-07-12 01:33:09  fraud_Parisian, Schiller and Altenwerth
# 136102    2020-08-08 03:31:20  fraud_Parisian, Schiller and Altenwerth
# 213887    2020-09-05 03:13:28  fraud_Parisian, Schiller and Altenwerth
# 282286    2020-10-04 22:45:15  fraud_Parisian, Schiller and Altenwerth
# 447759    2020-12-07 23:14:25  fraud_Parisian, Schiller and Altenwerth
# 491539    2020-12-17 19:42:04  fraud_Parisian, Schiller and Altenwerth
#
#          category      amt gender              city state    zip  city_pop  \
# 21668    misc_net   790.35      F          San Jose    CA  95148    973849
# 49909    misc_net   666.70      M           Houston    TX  77027   2906700
# 72074    misc_net   893.06      F    West Frankfort    IL  62896     12626
# 74075    misc_net   800.90      F       Chattanooga    TN  37411    198659
# 276198   misc_net   874.45      F          Campbell    NE  68932       493
# 344578   misc_net   737.68      M            Fulton    OH  43321       267
# 395807   misc_net   768.84      M            Bolton    NC  28423      2290
# 552077   misc_net   737.76      M       Mount Perry    OH  43760      1831
# 569571   misc_net   836.37      M           Arcadia    OH  44804      1202
# 635379   misc_net   909.14      M             Omaha    NE  68117    518429
# 673054   misc_net   736.16      M      Cross Plains    TX  76443      1897
# 746726   misc_net   941.50      M            Bryant    WI  54418      1080
# 987747   misc_net   806.03      F          Goodrich    MI  48438      6951
# 1059729  misc_net   667.18      F          Bay City    OR  97107      1530
# 1068939  misc_net   765.02      M  West Long Branch    NJ   7764      8097
# 1097512  misc_net   818.45      M             Iliff    CO  80736       648
# 1186843  misc_net  1046.12      M             Cross    SC  29436      4471
# 1222953  misc_net   729.05      F           Karnack    TX  75661      2807
# 1228626  misc_net   804.37      M               Leo    IN  46765      5341
# 1290489  misc_net   802.56      F        Stittville    NY  13469       847
# 1290504  misc_net   783.60      F        Mc Cracken    KS  67556       320
# 58974    misc_net   814.90      M          Lonsdale    MN  55046      5211
# 136102   misc_net   954.19      F        Georgetown    MN  56546       346
# 213887   misc_net   859.07      F        Birmingham    AL  35211    493806
# 282286   misc_net   790.28      F          Seligman    MO  65745      2693
# 447759   misc_net   694.47      M         Greenbush    VA  23357       776
# 491539   misc_net   759.36      M         Leetsdale    PA  15056      1140
#
#                                    job   unix_time  is_fraud    distance  age  \
# 21668                   Science writer  1326498334         1   49.672104   69
# 49909     Community development worker  1327874723         1   10.008444   63
# 72074        Trading standards officer  1329011668         1  102.172722   29
# 74075       Contracting civil engineer  1329085345         1  135.532045   80
# 276198              Surveyor, minerals  1337205803         1   32.767736   84
# 344578              Facilities manager  1339370015         1   78.331095   20
# 395807            Engineer, biomedical  1341010556         1   80.594845   79
# 552077               Barrister's clerk  1345810489         1   67.428907   71
# 569571                         Curator  1346342383         1   57.322426   92
# 635379        Surveyor, land/geomatics  1348779201         1   95.038709   29
# 673054         Chief Operating Officer  1350166597         1   33.793848   71
# 746726     Information systems manager  1353021874         1   25.268139   46
# 987747       Learning disability nurse  1360206151         1   78.493112   39
# 1059729            Colour technologist  1363401443         1   18.852353   38
# 1068939            Mechanical engineer  1363730793         1   94.587736   61
# 1097512          Community arts worker  1364770616         1   25.118238   55
# 1186843         Occupational hygienist  1368236813         1   56.347724   51
# 1222953                    Chiropodist  1369524248         1   82.490341   94
# 1228626            Biomedical engineer  1369693974         1   95.699223   30
# 1290489                Systems analyst  1371598393         1   35.634196   29
# 1290504              Film/video editor  1371598707         1   67.359675   63
# 58974           Chief Strategy Officer  1373592789         1   26.047366   38
# 136102   Research officer, trade union  1375932680         1   69.081550   48
# 213887   Operational investment banker  1378350808         1   99.360614   24
# 282286            Engineer, biomedical  1380926715         1   23.415989   57
# 447759                    Psychiatrist  1386458065         1   83.278630   75
# 491539        Administrator, education  1387309324         1   66.437662   38
#
#          fraud_merchant_pct  merchant_ordinal
# 21668             93.103448               693
# 49909             93.103448               693
# 72074             93.103448               693
# 74075             93.103448               693
# 276198            93.103448               693
# 344578            93.103448               693
# 395807            93.103448               693
# 552077            93.103448               693
# 569571            93.103448               693
# 635379            93.103448               693
# 673054            93.103448               693
# 746726            93.103448               693
# 987747            93.103448               693
# 1059729           93.103448               693
# 1068939           93.103448               693
# 1097512           93.103448               693
# 1186843           93.103448               693
# 1222953           93.103448               693
# 1228626           93.103448               693
# 1290489           93.103448               693
# 1290504           93.103448               693
# 58974             93.103448               693
# 136102            93.103448               693
# 213887            93.103448               693
# 282286            93.103448               693
# 447759            93.103448               693
# 491539            93.103448               693

# %%
new_df["state"].value_counts().reset_index().sort_values(by="count", ascending = False)[:15].sum()
# Out:
# state    NYTXPACAOHFLILMIALMOMNVASCWIKY
# count                             10651
# dtype: object

# %%
(10651 / new_df.shape[0]) * 100
# Out:
# 55.18081027872759

# %%
top_15_states = new_df["state"].value_counts().reset_index().sort_values(by="count", ascending = False)[:15].get("state").tolist()

# %%
new_df["state_cat"] = new_df["state"].apply(lambda x: x if x in top_15_states else "Other")

# %%
state_freq = new_df['state'].value_counts(normalize=True)
new_df['state_encoded'] = new_df['state'].map(state_freq)

# %%
new_df.sample(2)
# Out:
#         trans_date_trans_time                   merchant     category     amt  \
# 404190    2020-11-27 13:21:25      fraud_Goyette-Gerhold    kids_pets   80.01
# 1288644   2020-06-18 02:01:43  fraud_Schamberger-O'Keefe  grocery_pos  350.75
#
#         gender       city state    zip  city_pop                         job  \
# 404190       M    Hancock    MD  21750      3766          Press photographer
# 1288644      F  Henderson    WV  25106       642  Building services engineer
#
#           unix_time  is_fraud   distance  age  fraud_merchant_pct  \
# 404190   1385558485         0  72.951857   41           11.764706
# 1288644  1371520903         1  52.013962   78           61.904762
#
#          merchant_ordinal state_cat  state_encoded
# 404190                 29     Other       0.020671
# 1288644               543     Other       0.017977

# %%
new_df.drop(columns = ["state", "city", "merchant", "zip", "unix_time"], inplace = True)

# %%
new_df.sample(2)
# Out:
#        trans_date_trans_time category     amt gender  city_pop  \
# 984416   2020-02-04 14:38:06   travel    8.10      F      3684
# 733753   2019-11-09 23:03:54     home  277.15      F    409656
#
#                      job  is_fraud   distance  age  fraud_merchant_pct  \
# 984416          Musician         0  11.118083   43            25.00000
# 733753  Textile designer         1  58.700107   94            29.62963
#
#         merchant_ordinal state_cat  state_encoded
# 984416               182     Other       0.014610
# 733753               252     Other       0.018029

# %%
new_df.job.nunique()
# Out:
# 497

# %%
sector_bag = {
    "IT": ["engineer", "developer", "programmer", "software", "IT", "technician", "architect", "system", "network", 
           "administrator", "data scientist", "cybersecurity", "web developer", "analyst", "database", "devops"],
    
    "Education": ["teacher", "professor", "educator", "trainer", "lecturer", "scientist", "Orthoptist", "tutor", 
                  "principal", "instructor", "counselor", "academic", "researcher", "dean", "school", "headmaster"],
    
    "Healthcare": ["doctor", "nurse", "medical", "therapist", "pharmacist", "health", "surgeon", "dentist", "clinician", 
                   "physician", "optometrist", "radiologist", "paramedic", "midwife", "veterinarian", "psychiatrist"],
    
    "Finance": ["analyst", "accountant", "auditor", "banker", "financial", "investment", "controller", "broker", 
                "consultant", "treasurer", "loan officer", "trader", "actuary", "economist", "portfolio", "credit"],
    
    "Marketing": ["manager", "executive", "specialist", "consultant", "advertising", "public relations", "strategist", 
                  "director", "coordinator", "brand", "SEO", "content", "digital", "market research", "social media", 
                  "copywriter"],
    
    "Manufacturing": ["operator", "mechanic", "assembler", "fabricator", "engineer", "technician", "welder", 
                      "planner", "quality", "machinist", "production", "inspector", "supervisor", "foreman", 
                      "toolmaker", "CNC"],
    
    "Retail": ["cashier", "salesperson", "store", "associate", "manager", "clerk", "shopkeeper", "merchandiser", 
               "assistant", "retail", "customer service", "sales", "inventory", "buyer", "stocker", "checkout"],
    
    "Legal": ["lawyer", "attorney", "paralegal", "judge", "legal", "solicitor", "notary", "clerk", "litigator", 
              "advocate", "barrister", "counsel", "magistrate", "prosecutor", "defense", "compliance"],
    
    "Hospitality": ["chef", "waiter", "bartender", "host", "manager", "receptionist", "housekeeper", "concierge", 
                    "caterer", "cook", "hotel", "tour guide", "event planner", "sous chef", "sommelier", "valet"],
    
    "Construction": ["builder", "carpenter", "electrician", "plumber", "architect", "project manager", "site manager", 
                     "surveyor", "foreman", "bricklayer", "roofer", "civil engineer", "construction", "contractor", 
                     "inspector", "draftsman"]
}

def assign_sector(x):
    for key in sector_bag:
        for role in sector_bag[key]:
            if x.find(role) != -1:
                return key
    return "Other"

# %%
new_df["job_sector"] = new_df["job"].apply(assign_sector)
job = new_df["job_sector"].value_counts().reset_index()
plt.pie(x = job.get("count"), labels = job.get("job_sector"),autopct='%1.1f%%')
plt.title("different job sectors")
# Out:
# Text(0.5, 1.0, 'different job sectors')

# %%
job_freq = new_df['job'].value_counts(normalize=True)
new_df['job_encoded'] = new_df['job'].map(job_freq)

# %%
new_df.sample(2)
# Out:
#        trans_date_trans_time        category     amt gender  city_pop  \
# 638188   2019-09-28 22:58:12    shopping_net  997.00      M    518429
# 303752   2019-05-27 15:32:29  health_fitness   18.15      M     23727
#
#                              job  is_fraud   distance  age  \
# 638188  Surveyor, land/geomatics         1  78.794150   29
# 303752     Community arts worker         0  51.987327   43
#
#         fraud_merchant_pct  merchant_ordinal state_cat  state_encoded  \
# 638188           63.095238               548     Other       0.020827
# 303752           16.666667                64     Other       0.022588
#
#        job_sector  job_encoded
# 638188      Other     0.005647
# 303752      Other     0.001761

# %%
new_df["gender"] = new_df["gender"].apply(lambda x: int(x == "M"))

# %%
new_df.drop(columns = ["job"], inplace = True)

# %%
new_df.sample(2)
# Out:
#        trans_date_trans_time        category     amt  gender  city_pop  \
# 490969   2019-08-02 21:15:36  health_fitness   77.23       1      1360
# 990901   2020-02-08 23:19:51    shopping_net  995.86       1    409656
#
#         is_fraud   distance  age  fraud_merchant_pct  merchant_ordinal  \
# 490969         0  49.061330   40           27.272727               218
# 990901         1  52.805981   39           67.857143               579
#
#        state_cat  state_encoded job_sector  job_encoded
# 490969        WI       0.023624      Other     0.002539
# 990901     Other       0.018029  Marketing     0.002487

# %%
new_df["trans_date_trans_time"] = pd.to_datetime(new_df["trans_date_trans_time"])

# %%
new_df["is_weekend"] = new_df["trans_date_trans_time"].dt.day_name().apply(lambda x : int((x == "Friday") | (x == "Sunday") | (x == "saturday")))

# %%
def day_period(x):
    if x >=0 and x < 6: return "Night"
    elif x>= 6 and x <= 12: return "Morning"
    elif x> 12 and x <= 15: return "Afternoon"
    elif x> 15 and x <= 20: return "Evening"
    elif x> 20 and x <= 24: return "Night"


new_df["day_period"] = new_df["trans_date_trans_time"].dt.hour.apply(day_period)

# %%
new_df["trans_month"] = new_df["trans_date_trans_time"].dt.month_name()

# %%
new_df.drop(columns = ["trans_date_trans_time"], inplace = True)

# %%
new_df.sample(2)
# Out:
#        category    amt  gender  city_pop  is_fraud   distance  age  \
# 767417     home  77.04       0   1526206         0  24.453220   52
# 64686    travel   6.24       1     33917         0  45.153903   47
#
#         fraud_merchant_pct  merchant_ordinal state_cat  state_encoded  \
# 767417           34.782609               322        PA       0.059735
# 64686            20.000000               104     Other       0.020671
#
#        job_sector  job_encoded  is_weekend day_period trans_month
# 767417      Other     0.002746           1    Evening    November
# 64686       Other     0.000777           0    Evening        July

# %%
numerical = ["amt", "city_pop", "distance", "age", "fraud_merchant_pct", "merchant_ordinal", "state_encoded","job_encoded"]
categorical = [col for col in new_df.columns if col not in numerical]
categorical, numerical
# Out:
# (['category',
#   'gender',
#   'is_fraud',
#   'state_cat',
#   'job_sector',
#   'is_weekend',
#   'day_period',
#   'trans_month'],
#  ['amt',
#   'city_pop',
#   'distance',
#   'age',
#   'fraud_merchant_pct',
#   'merchant_ordinal',
#   'state_encoded',
#   'job_encoded'])

# %%
plt.figure(figsize = (20, 12))
cnt = 0
for column in categorical:
    cnt += 1
    plt.subplot(4, 2, cnt)
    sns.countplot(x = new_df[column])

# %%
plt.figure(figsize = (20, 12))
cnt = 0
for column in numerical:
    cnt += 1
    plt.subplot(4, 2, cnt)
    sns.kdeplot(x = new_df[column])

# %%
for col in numerical:
    print(f"col = {col}\tskewness = {new_df[col].skew()}")
# Out:
# col = amt	skewness = 1.554209483468879
# col = city_pop	skewness = 5.628461696119115
# col = distance	skewness = -0.21901062311800204
# col = age	skewness = 0.4973262762122213
# col = fraud_merchant_pct	skewness = -0.14798502512234427
# col = merchant_ordinal	skewness = -0.5319638334159288
# col = state_encoded	skewness = 0.8575072428764584
# col = job_encoded	skewness = 0.47826166724802566

# %%
plt.figure(figsize = (20, 8))
cnt = 0
for column in numerical:
    cnt += 1
    plt.subplot(2, 4, cnt)
    sns.boxplot(x = new_df[column])

# %%
plt.figure(figsize = (20, 35))
cnt = 0
for i in range(len(numerical)):
    for j in range(i + 1, len(numerical)):
        cnt += 1
        plt.subplot(10, 3, cnt)
        sns.scatterplot(x = new_df[numerical[i]], y = new_df[numerical[j]])

# %%
plt.figure(figsize = (10,8))
sns.heatmap(data = new_df[numerical].corr(), annot = True)
# Out:
# <Axes: >

# %%
new_df.drop(columns = ["merchant_ordinal"], inplace = True)
numerical.remove("merchant_ordinal")

# %%
numerical
# Out:
# ['amt',
#  'city_pop',
#  'distance',
#  'age',
#  'fraud_merchant_pct',
#  'state_encoded',
#  'job_encoded']

# %%
sns.barplot(y = new_df["amt"], x=new_df["is_fraud"])
# Out:
# <Axes: xlabel='is_fraud', ylabel='amt'>

# %%
sns.barplot(y = new_df["age"], x=new_df["is_fraud"], hue=new_df["gender"])
# Out:
# <Axes: xlabel='is_fraud', ylabel='age'>

# %%
sns.barplot(y = new_df["fraud_merchant_pct"], x=new_df["is_fraud"], hue = new_df["gender"])
# Out:
# <Axes: xlabel='is_fraud', ylabel='fraud_merchant_pct'>

# %%
sns.barplot(y = new_df["amt"], x=new_df["is_weekend"])
# Out:
# <Axes: xlabel='is_weekend', ylabel='amt'>

# %%
plt.figure(figsize = (12, 8))
sns.barplot(y = new_df["amt"], x=new_df["trans_month"])
# Out:
# <Axes: xlabel='trans_month', ylabel='amt'>

# %%
plt.figure(figsize = (20, 8))
sns.barplot(y = new_df["fraud_merchant_pct"], x=new_df["category"])
# Out:
# <Axes: xlabel='category', ylabel='fraud_merchant_pct'>

# %%
numerical, categorical
# Out:
# (['amt',
#   'city_pop',
#   'distance',
#   'age',
#   'fraud_merchant_pct',
#   'state_encoded',
#   'job_encoded'],
#  ['category',
#   'gender',
#   'is_fraud',
#   'state_cat',
#   'job_sector',
#   'is_weekend',
#   'day_period',
#   'trans_month'])

# %%
sns.barplot(y = new_df["amt"], x=new_df["day_period"], hue = new_df["gender"])
# Out:
# <Axes: xlabel='day_period', ylabel='amt'>

# %%
sns.heatmap(data=pd.crosstab(new_df["category"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='category'>

# %%
sns.heatmap(data=pd.crosstab(new_df["is_weekend"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='is_weekend'>

# %%
sns.heatmap(data=pd.crosstab(new_df["trans_month"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='trans_month'>

# %%
sns.heatmap(data=pd.crosstab(new_df["job_sector"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='job_sector'>

# %%
sns.heatmap(data=pd.crosstab(new_df["gender"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='gender'>

# %%
sns.heatmap(data=pd.crosstab(new_df["is_weekend"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='is_weekend'>

# %%
sns.heatmap(data=pd.crosstab(new_df["day_period"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='day_period'>

# %%
sns.heatmap(data=pd.crosstab(new_df["state_cat"],new_df["is_fraud"], normalize = "index") * 100, annot = True)
# Out:
# <Axes: xlabel='is_fraud', ylabel='state_cat'>

# %%
new_df.drop(columns = ["state_cat", "is_weekend"], inplace = True)

# %%
new_df.sample(2)
# Out:
#               category     amt  gender  city_pop  is_fraud    distance  age  \
# 938160        misc_net  894.06       0      2607         1   95.869125   29
# 15863   health_fitness   29.30       1      3688         0  103.391001   51
#
#         fraud_merchant_pct  state_encoded job_sector  job_encoded day_period  \
# 938160           77.500000       0.025852      Other     0.002331      Night
# 15863            33.333333       0.059735      Other     0.002176    Evening
#
#        trans_month
# 938160     January
# 15863         June

# %%
final_df1 = new_df.drop(columns = ["job_sector"])
final_df2 = new_df.drop(columns = ["job_encoded"])

# %%
oe = OrdinalEncoder(categories = [["February", "January", "March", "May", "October", "September","November", "April", "August", "June", "July", "December"]])

# %%
final_df1["trans_month"] = oe.fit_transform(final_df1[["trans_month"]])
final_df2["trans_month"] = oe.fit_transform(final_df2[["trans_month"]])

# %%
oe_period = OrdinalEncoder(categories = [["Night", "Evening", "Afternoon", "Morning"]])
final_df1["day_period"] = oe_period.fit_transform(final_df1[["day_period"]])
final_df2["day_period"] = oe_period.fit_transform(final_df2[["day_period"]])

# %%
ohe = OneHotEncoder(sparse_output = False, drop = 'first')

# %%
ohe_array = ohe.fit_transform(final_df1[["category"]])

# %%
ohe_column = ohe.get_feature_names_out()
ohe_column
# Out:
# array(['category_food_dining', 'category_gas_transport',
#        'category_grocery_net', 'category_grocery_pos',
#        'category_health_fitness', 'category_home', 'category_kids_pets',
#        'category_misc_net', 'category_misc_pos', 'category_personal_care',
#        'category_shopping_net', 'category_shopping_pos',
#        'category_travel'], dtype=object)

# %%
ohe_df = pd.DataFrame(ohe_array, columns = ohe_column, index=final_df1.index)

# %%
ohe_df.head()
# Out:
#          category_food_dining  category_gas_transport  category_grocery_net  \
# 517683                    0.0                     0.0                   0.0
# 1012042                   0.0                     0.0                   0.0
# 581404                    0.0                     0.0                   0.0
# 1094893                   0.0                     0.0                   0.0
# 433289                    0.0                     0.0                   0.0
#
#          category_grocery_pos  category_health_fitness  category_home  \
# 517683                    0.0                      0.0            0.0
# 1012042                   0.0                      1.0            0.0
# 581404                    1.0                      0.0            0.0
# 1094893                   0.0                      0.0            0.0
# 433289                    0.0                      0.0            0.0
#
#          category_kids_pets  category_misc_net  category_misc_pos  \
# 517683                  0.0                0.0                0.0
# 1012042                 0.0                0.0                0.0
# 581404                  0.0                0.0                0.0
# 1094893                 0.0                0.0                0.0
# 433289                  0.0                0.0                0.0
#
#          category_personal_care  category_shopping_net  category_shopping_pos  \
# 517683                      0.0                    0.0                    1.0
# 1012042                     0.0                    0.0                    0.0
# 581404                      0.0                    0.0                    0.0
# 1094893                     0.0                    0.0                    1.0
# 433289                      0.0                    1.0                    0.0
#
#          category_travel
# 517683               0.0
# 1012042              0.0
# 581404               0.0
# 1094893              0.0
# 433289               0.0

# %%
model_df = pd.concat([final_df1, ohe_df], axis = 1)

# %%
model_df.sample(2)
# Out:
#             category     amt  gender  city_pop  is_fraud   distance  age  \
# 116112   grocery_pos  287.69       1      1735         1   44.35133   34
# 717549  shopping_net    1.19       0    270712         0  123.48135   53
#
#         fraud_merchant_pct  state_encoded  job_encoded  ...  \
# 116112           63.157895       0.022588     0.004922  ...
# 717549           81.132075       0.029945     0.005647  ...
#
#         category_grocery_pos  category_health_fitness  category_home  \
# 116112                   1.0                      0.0            0.0
# 717549                   0.0                      0.0            0.0
#
#         category_kids_pets  category_misc_net  category_misc_pos  \
# 116112                 0.0                0.0                0.0
# 717549                 0.0                0.0                0.0
#
#         category_personal_care  category_shopping_net  category_shopping_pos  \
# 116112                     0.0                    0.0                    0.0
# 717549                     0.0                    1.0                    0.0
#
#         category_travel
# 116112              0.0
# 717549              0.0
#
# [2 rows x 25 columns]

# %%
model_df.drop(columns = ["category"], inplace = True)

# %%
model_df.columns
# Out:
# Index(['amt', 'gender', 'city_pop', 'is_fraud', 'distance', 'age',
#        'fraud_merchant_pct', 'state_encoded', 'job_encoded', 'day_period',
#        'trans_month', 'category_food_dining', 'category_gas_transport',
#        'category_grocery_net', 'category_grocery_pos',
#        'category_health_fitness', 'category_home', 'category_kids_pets',
#        'category_misc_net', 'category_misc_pos', 'category_personal_care',
#        'category_shopping_net', 'category_shopping_pos', 'category_travel'],
#       dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(model_df.drop(columns = ["is_fraud"]), model_df["is_fraud"], test_size = 0.2, random_state = 42)

# %%
skf = StratifiedKFold(n_splits=5, random_state=42, shuffle=True)

xgb = XGBClassifier(random_state=42)
params = {
    'n_estimators': [100, 150, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
    'gamma': [0, 0.1, 0.2]
}
 
hpt_xgb = GridSearchCV(estimator= xgb,
                   param_grid=params,
                   cv=skf,
                   verbose=1,
                   n_jobs=-1)

hpt_xgb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_typ...
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=42, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7],
#                          'n_estimators': [100, 150, 200],
#                          'subsample': [0.8, 0.9, 1.0]},
#              verbose=1)

# %%
xgb = XGBClassifier(**hpt_xgb.best_params_)
xgb.fit(x_train, y_train)
y_pred_xgb = xgb.predict(x_test)
print(classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1929
#            1       0.98      0.98      0.98      1932
#
#     accuracy                           0.98      3861
#    macro avg       0.98      0.98      0.98      3861
# weighted avg       0.98      0.98      0.98      3861

# %%
estimators = [
    ('xgb', xgb), 
]

vcls = VotingClassifier(estimators=estimators,voting="soft")

# %%
vcls.fit(x_train, y_train)
y_pred_vcls = vcls.predict(x_test)
print(classification_report(y_test, y_pred_vcls))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1929
#            1       0.98      0.98      0.98      1932
#
#     accuracy                           0.98      3861
#    macro avg       0.98      0.98      0.98      3861
# weighted avg       0.98      0.98      0.98      3861

# %%
print(roc_auc_score(y_test, y_pred_vcls))
# Out:
# 0.9790211675988267

# %%
y_pred_proba = vcls.predict_proba(x_test)[:, 1] 

# ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# AUC-ROC
auc_roc = roc_auc_score(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(10, 7))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (AUC = {auc_roc:.3f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--') 
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
joblib.dump(xgb, 'xgb_classifier_model.pkl')
